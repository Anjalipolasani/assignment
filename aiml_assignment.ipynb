# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.read_csv('/content/drive/MyDrive/forestfires.csv')

# %%
x=d['X']
y=d['area']
plt.plot(x,y)

# %%
x=d['Y']
y=d['area']
plt.plot(x,y)

# %%
x=d['FFMC']
y=d['area']
plt.plot(x,y)

# %%
x=d['DMC']
y=d['area']
plt.plot(x,y)

# %%
x=d['DC']
y=d['area']
plt.plot(x,y)

# %%
x=d['ISI']
y=d['area']
plt.plot(x,y)

# %%
x=d['temp']
y=d['area']
plt.plot(x,y)

# %%
x=d['RH']
y=d['area']
plt.plot(x,y)

# %%
x=d['wind']
y=d['area']
plt.plot(x,y)

# %%
x=d['rain']
y=d['area']
plt.plot(x,y)
